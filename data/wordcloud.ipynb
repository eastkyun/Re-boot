# %%
# !pip install konlpy
# Out:
# Requirement already satisfied: konlpy in d:\anaconda3\lib\site-packages (0.6.0)
# Requirement already satisfied: lxml>=4.1.0 in d:\anaconda3\lib\site-packages (from konlpy) (4.8.0)
# Requirement already satisfied: JPype1>=0.7.0 in d:\anaconda3\lib\site-packages (from konlpy) (1.4.0)
# Requirement already satisfied: numpy>=1.6 in d:\anaconda3\lib\site-packages (from konlpy) (1.22.3)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
from konlpy.tag import Okt
from PIL import Image
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('./finance_word.csv')

# %%
a = ['1','2','3']
''.join(a)
# Out:
# '123'

# %%
data =''.join(list(df.iloc[:,-1]))

# %%
c = Counter(words) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함

# %%
okt = Okt()
nouns = okt.nouns(data) # 명사만 추출

words = [n for n in nouns if len(n) > 1] # 단어의 길이가 1개인 것은 제외

c = Counter(words) # 위에서 얻은 words를 처리하여 단어별 빈도수 형태의 딕셔너리 데이터를 구함

# %%
wc = WordCloud(font_path='malgun', width=400, height=400, scale=2.0, max_font_size=250)
gen = wc.generate_from_frequencies(c)
plt.figure()
plt.imshow(gen)

# %%
df.iloc[386,:]
# Out:
# title           영향력계수
# contents    후방연쇄효과 참조
# Name: 386, dtype: object

# %%
df.iloc[386,:].contents='후방연쇄효과 참조'

# %%
data
